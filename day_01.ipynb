# %%
from oj_tools import run_judge
from day_01_testcase import *

# %% [markdown]
# ### 1. A+B problem
#
# **题目描述**
#
# 传入两个整数 `A` 和 `B`，请计算它们的和并返回结果。

# %%
class Solution_1:
    def solve(self, a: int, b: int) -> int:
        """
        计算 A + B 的结果并返回
        :param a: 整数
        :param b: 整数
        :return: 两个整数的和
        """
        return a + b# 在下方给出你的代码实现

# %% [markdown]
# 运行如下单元格测评结果

# %%
run_judge(Solution_1, test_cases_1)
# Out:
# ID    | 结果         | 耗时 (ms)      | 内存峰值 (KB)
# ------------------------------------------------------------
# 1     | ✅ Passed   | 0.0133       | 0.20
# 2     | ✅ Passed   | 0.0087       | 0.26
# 3     | ✅ Passed   | 0.0045       | 0.20
# 4     | ✅ Passed   | 0.0048       | 0.23
# 5     | ✅ Passed   | 0.0050       | 0.23
# 6     | ✅ Passed   | 0.0040       | 0.23
# 7     | ✅ Passed   | 0.0032       | 0.20
# 8     | ✅ Passed   | 0.0033       | 0.20
# 9     | ✅ Passed   | 0.0038       | 0.23
# 10    | ✅ Passed   | 0.0038       | 0.23
# 11    | ✅ Passed   | 0.0031       | 0.20
# 12    | ✅ Passed   | 0.0037       | 0.23
# ------------------------------------------------------------
# 🏁 评测完成: 12/12 通过

# %% [markdown]
# ### 2. 数组之和
#
# **题目描述**
#
# 传入一个一位数字数组，如[1,2,3,4,5], 给出这个数字的和，不允许调用数组自带函数

# %%
class Solution_2:
    def solve(self, nums: list) -> int:
        """
        计算数组中所有数字的和
        注意：不允许使用 sum(nums)
        """
        total = 0

        for num in nums:
            total += num
        
        return total

# %%
run_judge(Solution_2, test_cases_2)
# Out:
# ID    | 结果         | 耗时 (ms)      | 内存峰值 (KB)
# ------------------------------------------------------------
# 1     | ✅ Passed   | 0.0175       | 0.24
# 2     | ✅ Passed   | 0.0081       | 0.30
# 3     | ✅ Passed   | 0.0052       | 0.24
# 4     | ✅ Passed   | 0.0047       | 0.24
# 5     | ✅ Passed   | 0.0042       | 0.24
# 6     | ✅ Passed   | 0.0477       | 0.30
# 7     | ✅ Passed   | 0.0046       | 0.24
# ------------------------------------------------------------
# 🏁 评测完成: 7/7 通过

# %% [markdown]
# ### 3. 张量入门
#
# 深度学习中，数据流动的基本单位是张量，其学术定义为由数值组成的$n$维（有时候也叫维度(Dim)叫轴(Axis)）数组，例如：
#
# - $1$ 轴（Axis）张量：向量（Vector）。
# - $2$ 轴张量：矩阵（Matrix）。
# - $2$ 轴以上：统称张量。
#
# 向量和矩阵只是张量在1维和2维情况下的外号，他们本质上也是张量。
#
# > 张量，承态之器也，定信息之构，载信息之实，为场势作用之对象也
#
# - 承态之器 → 承载信息结构和状态，模型/算法的核心操作对象
# - 定信息之构 → 结构（维度/轴/拓扑）决定信息可能的排列方式
# - 载信息之实 → 数值承载具体信息
# - 为场势作用之对象也 → 受算子作用而变化，是变化发生的媒介
#
# #### 3.1 学习任务
#
# https://zh.d2l.ai/chapter_preliminaries/ndarray.html
#
# 学习该链接，给出如下笔记，并准备讲解
#
# - [ ] 如何创建张量
# - [ ] 如何查看张量的形状
# - [ ] 如何索引张量中特定元素或者切片张量
# - [ ] 张量-按元素运算的概念 （Element-wise）
